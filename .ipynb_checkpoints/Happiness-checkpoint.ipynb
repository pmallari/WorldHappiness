# %% [markdown]
# # Correlation of GDP to Happiness Score
#
# This is an analysis effort to understand what and how different factors contribute to a country's 'Happiness' metric.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
style.use('ggplot')

# %matplotlib inline
pd.options.display.float_format = '{:,.4f}'.format

# %%
# Declare constants in years included in analysis for loop

years = [2015, 2016, 2017]

# %%
#Importing data from csv files

df1 = pd.read_csv('2015.csv')
df2 = pd.read_csv('2016.csv')
df3 = pd.read_csv('2017.csv')

# %%
#Looking at sample data from 2015

df1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1           7.5870
# 1      Iceland  Western Europe               2           7.5610
# 2      Denmark  Western Europe               3           7.5270
# 3       Norway  Western Europe               4           7.5220
# 4       Canada   North America               5           7.4270
#
#    Standard Error  Economy (GDP per Capita)  Family  Health (Life Expectancy)  \
# 0          0.0341                    1.3965  1.3495                    0.9414
# 1          0.0488                    1.3023  1.4022                    0.9478
# 2          0.0333                    1.3255  1.3606                    0.8746
# 3          0.0388                    1.4590  1.3310                    0.8852
# 4          0.0355                    1.3263  1.3226                    0.9056
#
#    Freedom  Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
# Resize sns plots

sns.set(rc={'figure.figsize':(6,6)})

# Display correlations of features of the 2015 dataset
# Darker colors show stronger correlation with 

heatmap = sns.heatmap(df1.drop(columns = ['Happiness Rank', 'Standard Error']).corr(), cmap="Blues", annot = True)

# %%
# Display correlation matrices and store correlations per year in a dataframe

# Correlation 2015
print("Correlation of Happiness Score to the features in the year 2015 \n")
corr = pd.DataFrame(df1.corr()['Happiness Score'].sort_values(ascending = False)[1:-2])
corr.rename(columns = {'Happiness Score':'Happ Score 2015'}, inplace = True)
print(df1.corr()['Happiness Score'].sort_values(ascending = False)[1:-2])
print("\n\n")

# Correlation 2016
print("Correlation of Happiness Score to the features in the year 2016 \n")
corr['Happ Score 2016'] = df2.corr()['Happiness Score'].sort_values(ascending = False)[3:-1]
print(df2.corr()['Happiness Score'].sort_values(ascending = False)[3:-1])
print("\n\n")

# Correlation 2017
print("Correlation of Happiness Score to the features in the year 2017 \n")
corr['Happ Score 2017'] = df3.corr()['Happiness Score'].sort_values(ascending = False)[3:-1]
print(df3.corr()['Happiness Score'].sort_values(ascending = False)[3:-1])
# Out:
# Correlation of Happiness Score to the features in the year 2015
#
# Economy (GDP per Capita)        0.7810
# Family                          0.7406
# Health (Life Expectancy)        0.7242
# Freedom                         0.5682
# Dystopia Residual               0.5305
# Trust (Government Corruption)   0.3952
# Generosity                      0.1803
# Name: Happiness Score, dtype: float64
#
#
#
# Correlation of Happiness Score to the features in the year 2016
#
# Economy (GDP per Capita)        0.7903
# Health (Life Expectancy)        0.7654
# Family                          0.7393
# Freedom                         0.5668
# Dystopia Residual               0.5437
# Trust (Government Corruption)   0.4020
# Generosity                      0.1568
# Name: Happiness Score, dtype: float64
#
#
#
# Correlation of Happiness Score to the features in the year 2017
#
# Economy (GDP per Capita)        0.8125
# Health (Life Expectancy)        0.7820
# Family                          0.7527
# ...

# %%
#Comparative intensity between years

sns.heatmap(corr, cmap = 'winter')
plt.show()

# %% [markdown]
# We see that the factors that greatly contribute to a country's happiness is the Economy, Health, and Family.

# %%
## Creating a dataframe of country and happiness scores

# Merge the 2015 and 2016 Happiness Scores based on country
happ_score = pd.merge(df1[['Country','Happiness Score']],
                      df2[['Country','Happiness Score']], 
                      on = 'Country', how = 'inner')

#Renaming columns
happ_score.rename(columns={'Happiness Score_x': 'Happiness Score 2015', 
                           'Happiness Score_y': 'Happiness Score 2016'}, 
                            inplace = True)

#Merge data with 2017 data
happ_score = pd.merge(happ_score,df3[['Country','Happiness Score']], 
                                      on = 'Country', how = 'inner')

#Renaming column
happ_score.rename(columns={'Happiness Score': 'Happiness Score 2017'}, inplace = True)

#Peek at the first 10 rows of data
happ_score.head(10)
# Out:
#        Country  Happiness Score 2015  Happiness Score 2016  \
# 0  Switzerland                7.5870                7.5090
# 1      Iceland                7.5610                7.5010
# 2      Denmark                7.5270                7.5260
# 3       Norway                7.5220                7.4980
# 4       Canada                7.4270                7.4040
# 5      Finland                7.4060                7.4130
# 6  Netherlands                7.3780                7.3390
# 7       Sweden                7.3640                7.2910
# 8  New Zealand                7.2860                7.3340
# 9    Australia                7.2840                7.3130
#
#    Happiness Score 2017
# 0                7.4940
# 1                7.5040
# 2                7.5220
# 3                7.5370
# 4                7.3160
# 5                7.4690
# 6                7.3770
# 7                7.2840
# 8                7.3140
# 9                7.2840

# %%
#Check for null
happ_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 4 columns):
# Country                 146 non-null object
# Happiness Score 2015    146 non-null float64
# Happiness Score 2016    146 non-null float64
# Happiness Score 2017    146 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 5.7+ KB

# %% [markdown]
# Note that there are no null objects in the dataframe. That is because we used 'inner' in dataframe merging to remove any lines that are not found in all year datasets.

# %%
#Store happiness score per country for future use

happ_score.to_csv('HappScore_Country')

# %% [markdown]
# # GDP
#
# We first analyze how GDP has changed and see its trend among countries.

# %%
#Merge GDP from 2015 and 2016
happ_gdp = pd.merge(df1[['Country','Economy (GDP per Capita)']],
                    df2[['Country','Economy (GDP per Capita)']], 
                    on = 'Country', how = 'inner')

#Renaming columns
happ_gdp.rename(columns={'Economy (GDP per Capita)_x': 'GDP 2015', 
                         'Economy (GDP per Capita)_y': 'GDP 2016'}, 
                         inplace = True)

#Merge GDP from 2017
happ_gdp = pd.merge(happ_gdp,df3[['Country','Economy (GDP per Capita)']], 
                                  on = 'Country', how = 'inner')

#Renaming columns
happ_gdp.rename(columns={'Economy (GDP per Capita)': 'GDP 2017'}, inplace = True)

happ_gdp.head(10)
# Out:
#        Country  GDP 2015  GDP 2016  GDP 2017
# 0  Switzerland    1.3965    1.5273    1.5650
# 1      Iceland    1.3023    1.4267    1.4806
# 2      Denmark    1.3255    1.4418    1.4824
# 3       Norway    1.4590    1.5774    1.6165
# 4       Canada    1.3263    1.4402    1.4792
# 5      Finland    1.2902    1.4060    1.4436
# 6  Netherlands    1.3294    1.4647    1.5039
# 7       Sweden    1.3317    1.4518    1.4944
# 8  New Zealand    1.2502    1.3607    1.4057
# 9    Australia    1.3336    1.4444    1.4844

# %%
#Merge happiness score with gdp

score_and_gdp = pd.merge(happ_score, happ_gdp, on = 'Country', how = 'inner')

score_and_gdp.head()
# Out:
#        Country  Happiness Score 2015  Happiness Score 2016  \
# 0  Switzerland                7.5870                7.5090
# 1      Iceland                7.5610                7.5010
# 2      Denmark                7.5270                7.5260
# 3       Norway                7.5220                7.4980
# 4       Canada                7.4270                7.4040
#
#    Happiness Score 2017  GDP 2015  GDP 2016  GDP 2017
# 0                7.4940    1.3965    1.5273    1.5650
# 1                7.5040    1.3023    1.4267    1.4806
# 2                7.5220    1.3255    1.4418    1.4824
# 3                7.5370    1.4590    1.5774    1.6165
# 4                7.3160    1.3263    1.4402    1.4792

# %%
#Plot GDP and Happiness Score for 2015

gdp_happiness_plot = sns.regplot(x = f'GDP 2015', y = f'Happiness Score 2015', 
                                 data = score_and_gdp, label = f'Linear 2015',
                                 color = 'green')
plt.title("GDP vs Happiness Score in 2015")
plt.ylabel("Happiness Score")
plt.xlabel("GDP")
plt.show()

# %%
#Plot GDP and Happiness Score for 2016

ggdp_happiness_plot = sns.regplot(x = f'GDP 2016', y = f'Happiness Score 2016', 
                                 data = score_and_gdp, label = f'Linear 2016',
                                 color = 'blue')
plt.title("GDP vs Happiness Score in 2016")
plt.ylabel("Happiness Score")
plt.xlabel("GDP")
plt.show()

# %%
#Plot GDP and Happiness Score for 2017

ggdp_happiness_plot = sns.regplot(x = f'GDP 2017', y = f'Happiness Score 2017', 
                                 data = score_and_gdp, label = f'Linear 2017',
                                 color = 'orange')
plt.title("GDP vs Happiness Score in 2017")
plt.ylabel("Happiness Score")
plt.xlabel("GDP")
plt.show()

# %%
for i in years:
    ggdp_happiness_plot = sns.regplot(x = f'GDP {i}', y = f'Happiness Score {i}', 
                                      data = score_and_gdp, label = f'Linear {i}')

plt.title("GDP vs Happiness Score from 2015 - 2017")
plt.ylabel("Happiness Score")
plt.xlabel("GDP")
plt.show()

# %% [markdown]
# Based on the graphs above, GDP is strongly correlated to the Happiness Score but the contribution of the GDP to the Happiness Score is decreasing over the years.
